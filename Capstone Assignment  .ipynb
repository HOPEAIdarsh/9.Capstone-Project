# %%
import pandas as pd
dataset=pd.read_csv('Hotel Reservations.csv')
dataset
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
dataset.shape
# Out:
# (36275, 19)

# %%
dataset.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
dataset.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %%
dataset.describe(include=object)
# Out:
#        Booking_ID type_of_meal_plan room_type_reserved market_segment_type  \
# count       36275             36275              36275               36275
# unique      36275                 4                  7                   5
# top      INN00001       Meal Plan 1        Room_Type 1              Online
# freq            1             27835              28130               23214
#
#        booking_status
# count           36275
# unique              2
# top      Not_Canceled
# freq            24390

# %%
# Number of total bookings
total_bookings = len(dataset)
# Number of canceled bookings
canceled_bookings = len(dataset[dataset['booking_status'] == 'Canceled'])
# Percentage of cancellations
cancel_percentage = (canceled_bookings / total_bookings) * 100

# %%
# Create and display the matrix
matrix = {
    'Status': ['Canceled', 'Not_Canceled'],
    'Number': [canceled_bookings, total_bookings - canceled_bookings],
    'Percentage': [cancel_percentage, 100 - cancel_percentage],
    'Total': [total_bookings, total_bookings]
}
print(pd.DataFrame(matrix))
# 32.7% - cancel. 67.2% not canceled. i want to study how can i reduce the number of cancellations.
# Out:
#          Status  Number  Percentage  Total
# 0      Canceled   11885   32.763611  36275
# 1  Not_Canceled   24390   67.236389  36275

# %% [markdown]
# # Handling Outliers:

# %%
# visualization of the outliers for the numeric : avg_price_per_room, lead_time
import matplotlib.pyplot as plt
plt.boxplot(dataset.avg_price_per_room, showmeans=True)
plt.title('Boxplot of avg_price_per_room')
plt.show()

# %%
# removing the outliers,Calculate IQR for the column
Q1 = dataset['avg_price_per_room'].quantile(0.25)
Q3 = dataset['avg_price_per_room'].quantile(0.75)
IQR = Q3 - Q1

# %%
# Identify and remove outliers
dataset = dataset[~((dataset['avg_price_per_room'] < (Q1 - 1.5 * IQR)) | (dataset['avg_price_per_room'] > (Q3 + 1.5 * IQR)))]
print(dataset.shape, "2") # (34579, 19)
plt.boxplot(dataset.avg_price_per_room, showmeans=True)
plt.title('Boxplot of avg_price_per_room (After Removing Outliers)')
plt.show()
# Out:
# (34579, 19) 2

# %%
plt.boxplot(dataset.lead_time, showmeans=True)
plt.title('Boxplot of lead_time')
plt.show()
Q1 = dataset['lead_time'].quantile(0.25)
Q3 = dataset['lead_time'].quantile(0.75)
IQR = Q3 - Q1

# %%
dataset = dataset[~((dataset['lead_time'] < (Q1 - 1.5 * IQR)) | (dataset['lead_time'] > (Q3 + 1.5 * IQR)))]
print(dataset.shape, "3") # (33462, 19)
plt.boxplot(dataset.lead_time, showmeans=True)
plt.title('Boxplot of lead_time (After Removing Outliers)')
plt.show()
# Out:
# (33462, 19) 3

# %%
# Assuming no_of_adults, no_of_children and avg_price_per_room should be >= 0
dataset=  dataset[ dataset['no_of_adults'] >= 0]
dataset =  dataset[ dataset['no_of_children'] >= 0]
dataset =  dataset[ dataset['avg_price_per_room'] > 0]
dataset.shape, "4" # (33462, 19)

dataset =  dataset.drop_duplicates()
dataset.shape, "5" # (33462, 19)
# Out:
# ((33462, 19), '5')

# %%
# converting categorical columns to numeric , dropping the id column

dataset = dataset.drop('Booking_ID', axis=1)

# %%
# checking the relation between lean time and cancel
bins = [0, 7, 30, 90, float('inf')]
labels = ['Week', 'Month', '3 Months', 'More than 3 months']

# %%
# Create a new column for lead_time bins
dataset['lead_time_group'] = pd.cut(dataset['lead_time'], bins=bins, labels=labels, right=False)

# %%
# Initialize data for the stacked bar chart
bar_data = {}
for group in labels:
    subset = dataset[dataset['lead_time_group'] == group]
    bar_data[group] = {
        'Not_Canceled': len(subset[subset['booking_status'] == 'Not_Canceled']),
        'Canceled': len(subset[subset['booking_status'] == 'Canceled'])
    }

# Data to plot
labels = list(bar_data.keys())
not_canceled_counts = [bar_data[label]['Not_Canceled'] for label in labels]
canceled_counts = [bar_data[label]['Canceled'] for label in labels]

# %%
# Create the stacked bar plot
fig, ax = plt.subplots()
width = 0.5

p1 = plt.bar(labels, not_canceled_counts, width, color='green', label='Not_Canceled')
p2 = plt.bar(labels, canceled_counts, width, color='red', bottom=not_canceled_counts, label='Canceled')

# Add title and labels
plt.title('Booking Status by Lead Time Groups', fontdict={'fontsize': 16})
plt.xlabel('Lead Time Group', fontdict={'fontsize': 14})
plt.ylabel('Number of Bookings', fontdict={'fontsize': 14})

# Add a legend
plt.legend(title='Booking Status')

# Show the plot
plt.show()


dataset['market_segment_type'].value_counts()
# Out:
# Online           21725
# Offline           9589
# Corporate         2007
# Aviation           125
# Complementary       16
# Name: market_segment_type, dtype: int64

# %% [markdown]
# # Cancellation

# %%
# Initialize data for the bar chart
bar_data = {}
market_segments = dataset['market_segment_type'].unique()

for segment in market_segments:
    subset = dataset[dataset['market_segment_type'] == segment]
    total_bookings = len(subset)
    canceled_bookings = len(subset[subset['booking_status'] == 'Canceled'])

    if total_bookings > 0:  # Avoid division by zero
        cancel_percentage = (canceled_bookings / total_bookings) * 100
    else:
        cancel_percentage = 0

    bar_data[segment] = cancel_percentage
# Data to plot
labels = list(bar_data.keys())
cancel_percentages = [bar_data[label] for label in labels]

# Create the bar plot
fig, ax = plt.subplots()
plt.bar(labels, cancel_percentages, color='blue')  # You can change the color as needed

# Add title and labels
plt.title('Percentage of Cancellations ', fontdict={'fontsize': 16})
plt.xlabel('Market Segment', fontdict={'fontsize': 14})
plt.ylabel('Percentage of Cancellations', fontdict={'fontsize': 14})

# Annotate each bar with the corresponding percentage value
for i, v in enumerate(cancel_percentages):
    ax.text(i, v+0.2, "{:.2f}%".format(v), color='black', ha='center')
# Show the plot
plt.show()

# %% [markdown]
# # Machine Learning Workflow for Booking Cancellation Prediction

# %%
# Encoding Categorical Features
from sklearn.preprocessing import LabelEncoder
dataset_encoded = dataset.copy()
dataset_encoded = dataset_encoded.drop('lead_time_group', axis=1)

# List of columns to encode
columns_to_encode = ['type_of_meal_plan', 'room_type_reserved', 'market_segment_type', 'booking_status']
# Apply LabelEncoder to each column
for column in columns_to_encode:
    encoder = LabelEncoder()
    dataset_encoded[column] = encoder.fit_transform(dataset_encoded[column])

# Display the first few rows of the encoded DataFrame to see the changes
dataset.head()
dataset_encoded.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  0                           0                   0
# 1                  2                           0                   0
# 2                  0                           0                   0
# 3                  0                           0                   0
# 4                  2                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %%
# Data Splitting, predictors (features) and the target (label)
from sklearn.model_selection import train_test_split
X = dataset_encoded.drop('booking_status', axis=1)
y = dataset_encoded['booking_status']

# Split the data into training and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
"Training data size:", X_train.shape
"Test data size:", X_test.shape
# Out:
# ('Test data size:', (10039, 17))

# %%
# Model creation
# Create a Random Forest classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier on the training data
clf.fit(X_train, y_train)

# Print out the importance of each feature
feature_importances = clf.feature_importances_
for feature, importance in zip(X.columns, feature_importances):
    print(f"{feature}: {importance:.4f}")
# the most important feature is: lead_time: 0.3123


# Model Evaluation

# Predictions on training data
train_preds = clf.predict(X_train)

# Predictions on test data
test_preds = clf.predict(X_test)

# Accuracy
train_accuracy = accuracy_score(y_train, train_preds)
test_accuracy = accuracy_score(y_test, test_preds)

# Precision
train_precision = precision_score(y_train, train_preds)
test_precision = precision_score(y_test, test_preds)

# Recall
train_recall = recall_score(y_train, train_preds)
test_recall = recall_score(y_test, test_preds)

print()
print("Training Data Metrics:")
print(f"Accuracy: {train_accuracy:.4f}") # 0.9947
print(f"Precision: {train_precision:.4f}") # 0.9946
print(f"Recall: {train_recall:.4f}") # 0.9978

print("\nTest Data Metrics:")
print(f"Accuracy: {test_accuracy:.4f}") # 0.8960
print(f"Precision: {test_precision:.4f}") # 0.9061
print(f"Recall: {test_recall:.4f}") # 0.9449
print()
# Out:
# no_of_adults: 0.0238
# no_of_children: 0.0066
# no_of_weekend_nights: 0.0378
# no_of_week_nights: 0.0533
# type_of_meal_plan: 0.0171
# required_car_parking_space: 0.0064
# room_type_reserved: 0.0151
# lead_time: 0.3123
# arrival_year: 0.0219
# arrival_month: 0.0843
# arrival_date: 0.0964
# market_segment_type: 0.0541
# repeated_guest: 0.0027
# no_of_previous_cancellations: 0.0003
# no_of_previous_bookings_not_canceled: 0.0014
# avg_price_per_room: 0.1628
# no_of_special_requests: 0.1037
#
# Training Data Metrics:
# Accuracy: 0.9947
# Precision: 0.9946
# Recall: 0.9978
#
# Test Data Metrics:
# Accuracy: 0.8960
# Precision: 0.9061
# Recall: 0.9449

# %%
# remove overfitting
# Model creation # 2
# Create a Random Forest classifier
clf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    max_depth=10,              # Limit the depth of the tree
    min_samples_split=10,      # Minimum samples required to make a split
    min_samples_leaf=5,        # Minimum samples required to be a leaf node
    max_features='sqrt',       # Square root of total features will be used
    bootstrap=True             # Use bootstrap samples
)

# Train the classifier on the training data
clf.fit(X_train, y_train)

# Print out the importance of each feature
feature_importances = clf.feature_importances_
for feature, importance in zip(X.columns, feature_importances):
    print(f"{feature}: {importance:.4f}")
# the most important feature is: lead_time: 0.3785


# Model Evaluation

# Predictions on training data
train_preds = clf.predict(X_train)

# Predictions on test data
test_preds = clf.predict(X_test)

# Accuracy
train_accuracy = accuracy_score(y_train, train_preds)
test_accuracy = accuracy_score(y_test, test_preds)

# Precision
train_precision = precision_score(y_train, train_preds)
test_precision = precision_score(y_test, test_preds)

# Recall
train_recall = recall_score(y_train, train_preds)
test_recall = recall_score(y_test, test_preds)

print()
print("Training Data Metrics:")
print(f"Accuracy: {train_accuracy:.4f}") # 0.8829
print(f"Precision: {train_precision:.4f}") # 0.891
print(f"Recall: {train_recall:.4f}") # 0.9452

print("\nTest Data Metrics:")
print(f"Accuracy: {test_accuracy:.4f}") # 0.8691
print(f"Precision: {test_precision:.4f}") # 0.8775
# Out:
# no_of_adults: 0.0175
# no_of_children: 0.0016
# no_of_weekend_nights: 0.0221
# no_of_week_nights: 0.0219
# type_of_meal_plan: 0.0110
# required_car_parking_space: 0.0080
# room_type_reserved: 0.0067
# lead_time: 0.3785
# arrival_year: 0.0398
# arrival_month: 0.0668
# arrival_date: 0.0302
# market_segment_type: 0.0910
# repeated_guest: 0.0046
# no_of_previous_cancellations: 0.0002
# no_of_previous_bookings_not_canceled: 0.0026
# avg_price_per_room: 0.1227
# no_of_special_requests: 0.1748
#
# Training Data Metrics:
# Accuracy: 0.8829
# Precision: 0.8910
# Recall: 0.9452
#
# Test Data Metrics:
# Accuracy: 0.8691
# Precision: 0.8775
